# %% [markdown]
# # Breast Cancer Project – Análise Exploratória (EDA)
#
# ## 1. Importações iniciais

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 2. Carregar os dados

# %%
df = pd.read_csv('../data/raw/data.csv')
df.head()

# %% [markdown]
# ## 3. Exploração geral
# - Tipos de dados
# - Valores faltantes
# - Balanceamento da variável alvo

# %% [markdown]
# ## 4. Estatísticas descritivas

# %% [markdown]
# ## 5. Visualizações importantes
# - Histogramas
# - Boxplots
# - Correlação (heatmap)

# %% [markdown]
# ## 6. Conclusões da EDA
# Escreva em tópicos:
# - quais features parecem importantes
# - distribuição
# - possíveis problemas
