# %%
import sys
sys.path.append("..")

from src.inference.predict import PredictionPipeline
from src.config import SELECTED_FEATURES
import pandas as pd

pipeline = PredictionPipeline()

df = pd.read_csv("../data/processed/X_test_preprocessed.csv")

sample = df.iloc[0].to_dict()

pipeline.predict_single(sample)
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0    -0.770899     -2.006025       -0.764517   -0.71184        -0.158315
#
#    compactness_mean  concavity_mean  concave_points_mean  symmetry_mean  \
# 0           -0.6868       -0.662486            -0.574754      -0.535821
#
#    fractal_dimension_mean  ...  fractal_dimension_worst  radius_avg  \
# 0               -0.227607  ...                 0.060958   -0.808355
#
#    perimeter_avg  area_avg  concavity_avg  texture_avg  var_total  prediction  \
# 0      -0.774616  -0.66735      -0.500561    -1.671472   0.280026           0
#
#    prediction_label  probability_malignant
# 0            Benign               0.000335
#
# [1 rows x 39 columns]

# %%
pipeline.predict_batch(df.head(5))
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0    -0.770899     -2.006025       -0.764517  -0.711840        -0.158315
# 1     1.894726      0.966489        1.890816   1.956605         0.329304
# 2     0.560515     -0.781088        0.570440   0.358094         0.196381
# 3     0.071025      0.082201        0.091703  -0.047437         0.106832
# 4    -0.219873      2.637069       -0.237986  -0.284366        -0.247863
#
#    compactness_mean  concavity_mean  concave_points_mean  symmetry_mean  \
# 0         -0.686800       -0.662486            -0.574754      -0.535821
# 1          1.054116        2.230361             2.068127       1.412336
# 2          0.742144       -0.277843             0.125003       0.633797
# 3          0.190621        0.057540             0.236500       0.231854
# 4         -0.549198       -0.747404            -0.413058      -1.593184
#
#    fractal_dimension_mean  ...  fractal_dimension_worst  radius_avg  \
# ...

# %%
# same test as in 06_Model_Evaluation
# same result "0" = Benign
X_test  = pd.read_csv("../data/processed/X_test_preprocessed.csv")
X_test_sel = X_test[SELECTED_FEATURES]

pipeline.predict_single(X_test_sel.iloc[0].to_dict())
# Out:
#    concave_points_mean  concavity_worst  symmetry_worst  radius_avg  \
# 0            -0.574754        -0.306687        0.162547   -0.808355
#
#    perimeter_avg  area_avg  radius_mean  texture_mean  perimeter_mean  \
# 0      -0.774616  -0.66735    -0.770899     -2.006025       -0.764517
#
#    area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0   -0.71184        -0.158315           -0.6868       -0.662486
#
#    symmetry_mean  fractal_dimension_mean  prediction prediction_label  \
# 0      -0.535821               -0.227607           0           Benign
#
#    probability_malignant
# 0               0.000335
